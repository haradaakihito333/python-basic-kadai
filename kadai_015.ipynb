# %%
class Human:
  #コンストラクタの定義
  def __init__(self,name,age):
    self.name = name
    self.age = age

  #メソッドの定義
  def printinfo(self):
    print(self.name)
    print(self.age)

#インスタンス化
harada = Human("原田明人",51)

#メソッドにアクセス
harada.printinfo()
