# %%
from IPython.core.display import clear_output
arrays = ["水","金","地","火","木","土","天","海","冥"]

for array in arrays:
  print(array)

array = clear_output

while array != "冥":
  for array in arrays:
    print(array)
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
