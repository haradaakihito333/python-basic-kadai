# %%
from typing import ValuesView
from IPython.core.display import clear_output
arrays = ["水","金","地","火","木","土","天","海","冥"]

for array in arrays:
  print(array)

i = 0

while i > len(arrays):
  print(array)
  i= i + 1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
